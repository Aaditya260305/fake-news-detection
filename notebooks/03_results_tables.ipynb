# %% [markdown]
# # Results notebook — reproduce paper Tables I, III and Figs. 5/6
#
# Assumes you have already run `python -m src.train` for every model + every ablation mode.

# %%
import sys, json
from pathlib import Path
sys.path.insert(0, '..')
from src.config import load_config
from src.evaluate import emit_tables

cfg = load_config('../configs/default.yaml')
emit_tables(cfg, Path('../artifacts'), Path('../reports'))
print('done')

# %%
from IPython.display import Markdown
Markdown((Path('../reports') / 'table1_detection.md').read_text(encoding='utf-8'))

# %%
Markdown((Path('../reports') / 'table3_ablation.md').read_text(encoding='utf-8'))

# %%
from IPython.display import Image
Image(filename='../reports/figures/val_loss.png')
